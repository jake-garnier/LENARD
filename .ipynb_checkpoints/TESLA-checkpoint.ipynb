# %%
import pandas as pd
mse_list = 

df = pd.DataFrame(data=mse_list, columns=['dataid', 'TESLA'])
df = df.set_index('dataid')

df_total = pd.read_csv('full_results.csv')
df_total = df_total.set_index('dataid')
df_total = df_total.merge(df, left_on='dataid', right_on='dataid')
df_total.to_csv('full_results.csv')
df_total

# %%
import pandas as pd

total_list = []

for x in range(1, 937) :
    df_curr = pd.read_csv("%d_results.csv" % x, header=0)
    total_list.append([unique_series_indexes[x], df_curr['data'].tolist()])
    
df = pd.DataFrame(data=total_list, columns=['dataid', 'TESLA'])
df = df.set_index('dataid')

df_total = df_total[['ARIMA', 'Holt-Winters', 'LSTM-20-7', 'Actual']]
df_total = df_total.merge(df, left_on='dataid', right_on='dataid')
df_total = df_total[['TESLA', 'ARIMA', 'Holt-Winters', 'LSTM-20-7', 'Actual']]
df_total.to_csv('full_results.csv')
df_total
# Out:
#                                                     TESLA  \
# dataid
# 203     [0.50373, 0.55533, 0.5725399999999999, 0.54292...
# 1450    [1.2501, 1.1727, 1.0881, 0.9793299999999999, 0...
# 1524    [0.49391999999999997, 0.53706, 0.53718, 0.5779...
# 1731    [0.71699, 0.7206100000000001, 0.69276, 0.6802,...
# 2606    [1.8985, 1.7277, 1.6564, 1.6373, 1.9343, 1.610...
# 3687    [0.9363, 0.9898299999999999, 0.84246, 0.880239...
# 3864    [0.24191999999999997, 0.2551, 0.22557, 0.23171...
# 3938    [0.30563, 0.32511999999999996, 0.31801, 0.7789...
# 4495    [0.075928, 0.072199, 0.071742, 0.0683940000000...
# 4934    [0.2841, 0.18988, 0.18808, 0.22177, 0.23805, 0...
# 5938    [0.2612, 0.27633, 0.19877999999999998, 0.21338...
# 6377    [0.33275, 0.30135, 0.41686000000000006, 0.2767...
# 6547    [1.0516, 0.92175, 0.8902100000000001, 0.914679...
# 7062    [1.0889, 0.8697600000000001, 0.977989999999999...
# 7114    [0.20843000000000003, 0.18236, 0.17356, 0.1957...
# ...

# %%
len(range(3))
# Out:
# 3

# %%
df_curr = pd.read_csv("/ResearchDa%d_results.csv" % x, header=0)
