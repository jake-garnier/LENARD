# %%
import pandas as pd
mse_list = 

df = pd.DataFrame(data=mse_list, columns=['dataid', 'TESLA'])
df = df.set_index('dataid')

df_total = pd.read_csv('full_results.csv')
df_total = df_total.set_index('dataid')
df_total = df_total.merge(df, left_on='dataid', right_on='dataid')
df_total.to_csv('full_results.csv')
df_total

# %%
import pandas as pd

df = pd.read_csv('../../LowMEData/dataset_file_names.csv')
names = df['filename'].values

for x in range(len(names)) :
    
    df_test = pd.read_csv('../../LowMEData/' + names[x])
    split_point = int(len(df_test.index) * .8)

    if(df_test.columns[1] == 'Electricity:Facility [kW](Hourly)') :
        raw_values = df_test['Electricity:Facility [kW](Hourly)'].values
    else :
        raw_values = df_test['Electricity:Facility [J](Hourly)'].values
        
    new_df = pd.DataFrame()
    new_df['vals'] = raw_values
    new_df = new_df.set_index('vals')
    new_df.to_csv("../../tesla_data/tesla_input/%d.csv" % x )

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error

df = pd.read_csv('../../LowMEData/dataset_file_names.csv')
names = df['filename'].values

prediction_list = []
mse_list = []

for x in range(936) :
# print(x)
    df_test = pd.read_csv('../../LowMEData/' + names[x])
    split_point = int(len(df_test.index) * .8)
    
    if(df_test.columns[1] == 'Electricity:Facility [kW](Hourly)') :
        full = df_test['Electricity:Facility [kW](Hourly)'].values
    else :
        full = df_test['Electricity:Facility [J](Hourly)'].values
#     full = df_test['gas'].values
    # full = df_test['gas'].values
    
    # df_curr = pd.read_csv("ResearchData/%d_results.csv" % x, header=None)
    df_curr = pd.read_csv("../../tesla_data/%d_results.csv" % x, header=None)
    
    prediction_list.append(df_curr[0].tolist())
    
    print(len(df_curr[0]))
    split_point2 = int(len(df_curr[0]) * .8)
        
    mse_list.append(mean_squared_error(full[split_point:split_point + len(df_curr[0])][split_point2:], df_curr[0][split_point2:]))
    
    
# df_predictions = pd.DataFrame()
# df_predictions['TESLA'] = prediction_list

# df_mse = pd.DataFrame()
# df_mse['TESLA'] = mse_list

# df_mse
# Out:
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 875
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# 1752
# ...

# %%
df_mse = pd.DataFrame()
df_mse['tesla'] = mse_list
df_mse['id'] = range(936)
df_mse = df_mse.set_index('id')
df_mse.to_csv('low_tesla_mse_electricity.csv')
df_mse
# Out:
#         tesla
# id
# 0    0.008107
# 1    0.008241
# 2    0.019631
# 3    0.019507
# 4    0.019567
# ..        ...
# 931  0.008307
# 932  0.008283
# 933  0.008370
# 934  0.008387
# 935  0.008323
#
# [936 rows x 1 columns]

# %%
# df_mse.to_csv('ResearchData/tesla_mse_gas.csv')
df_predictions.to_csv('ResearchData/tesla_predictions_gas.csv')

# %%
import pandas as pd
df_curr = pd.read_csv("ResearchData/data2/%d_results.csv" % 1, header=None)
len(df_curr[0].values)
# Out:
# 1752

# %%
df = pd.read_csv('mse.csv')
df.mean()
# Out:
# id                   467.500000
# holt                   0.263957
# svr                    0.665638
# arima                  0.283822
# tesla                  0.018894
# lstm                   0.033454
# Mix Ex 3000 epoch      0.017875
# dtype: float64

# %%
mse = pd.DataFrame()
mse['mse'] = mse_list
mse.mean()
# Out:
# mse    0.379405
# dtype: float64

# %%
import pandas as pd
df_test = pd.read_csv('../../tesla_data/' + str(0) + '_results.csv', header=None)
df_test
# Out:
#             0
# 0     1.13350
# 1     0.98349
# 2     0.90941
# 3     0.89870
# 4     0.89604
# ...       ...
# 1747  3.23880
# 1748  3.01680
# 1749  2.86690
# 1750  2.63520
# 1751  2.20030
#
# [1752 rows x 1 columns]
